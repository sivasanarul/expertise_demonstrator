# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import os 

import scipy.sparse as sparse
import scipy.linalg as linalg
import numpy as np
import collections
import copy

import amfe
from amfe.utils.utils import OrderedSet
from amfe.cyclic.cyclic import SelectionOperator, apply_cyclic_symmetry, get_dofs, rotate_u, set_cyclic_modes_to_component
from amfe.cyclic.cyclic import create_voigt_rotation_matrix, assemble_cyclic_modes
from amfe.linalg.arnoldi import arnoldi_iteration, inverse_arnoldi_iteration, general_inverse_arnoldi_iteration, generalized_arnoldi_iteration
from amfe.linalg.arnoldi import lanczos, is_eigvec, nullspace, LinearSys, power_iteration, ProjLinearSys, compute_modes
from amfe.units import convert

# %%
mesh_folder = '/home/mlid150/Documents/Demonstrator/Safran Demonstrator/Meshes'
msh_name = r'safran_blisk.inp'
msh_file = os.path.join(mesh_folder,msh_name)
m = amfe.Mesh()
m.import_inp(msh_file,1000)
# Out:
# *************************************************************
#
# Loading Abaqus-mesh from /home/mlid150/Documents/Demonstrator/Safran Demonstrator/Meshes/safran_blisk.inp
# Can not read the given string list
# WARNING! 3D case were selected
# Mesh /home/mlid150/Documents/Demonstrator/Safran Demonstrator/Meshes/safran_blisk.inp successfully imported.
# Assign a material to a physical group.
# *************************************************************

# %%
from pyfeti import utils
utils.save_object(m,'mesh.pkl')

# %%
ax1 = amfe.plot3Dmesh(m)
#pltmesh.show(plot_nodes=False)
vlim=[0,175]
ax1.set_xlim(vlim)
ax1.set_ylim(vlim)
ax1.set_zlim(vlim)
#pltmesh.set_equal_axis_lim(vlim)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, 175)

# %%
print(m.get_elem_types())
print(m.get_phys_group_types())
# Out:
# {'Tri3', 'Tet4'}
# {'N_CYCLIC_DISQUE_ELSET', 'BLADE_2_7_ELSET', 'BLADE_2_3_SOLID_ELSET', 'DISK_1_4_ELSET', 'DISK_1_2_ELSET', 'DISK_1_3_ELSET', 'DISK_1_4_SOLID_ELSET', 'BLADE_2_2_SOLID_ELSET', 'BLADE_2_1_ELSET', 'E_PROFIL_ELSET', 'BLADE_2_7_SOLID_ELSET', 'DISK_1_3_SOLID_ELSET', 'DISK_1_6_SOLID_ELSET', 'DISK_1_1_SOLID_ELSET', 'N_INTERFACE_ELSET', 'DISK_1_1_ELSET', 'DISK_1_6_ELSET', 'CTC_ALL_ELSET', 'DISK_1_5_ELSET', 'BLADE_2_2_ELSET', 'BLADE_2_4_SOLID_ELSET', 'BLADE_2_3_ELSET', 'BLADE_2_4_ELSET', 'TGT_ALL_ELSET', 'BLADE_2_5_ELSET', 'BLADE_2_1_SOLID_ELSET', 'BLADE_2_6_SOLID_ELSET', 'BLADE_2_6_ELSET', 'DISK_1_2_SOLID_ELSET', 'DISK_1_5_SOLID_ELSET'}

# %%
map_string = lambda  i : 'DISK_1_%i_SOLID_ELSET' %i

# rename solid components

for i in range(1,7):
    m.change_tag_in_eldf('phys_group',map_string(i),'DISK')

# %%
print(m.get_phys_group_types())
# Out:
# {'N_CYCLIC_DISQUE_ELSET', 'BLADE_2_7_ELSET', 'BLADE_2_3_SOLID_ELSET', 'DISK_1_4_ELSET', 'DISK_1_2_ELSET', 'DISK_1_3_ELSET', 'BLADE_2_1_ELSET', 'BLADE_2_2_SOLID_ELSET', 'E_PROFIL_ELSET', 'BLADE_2_7_SOLID_ELSET', 'DISK', 'N_INTERFACE_ELSET', 'DISK_1_1_ELSET', 'DISK_1_6_ELSET', 'CTC_ALL_ELSET', 'DISK_1_5_ELSET', 'BLADE_2_2_ELSET', 'BLADE_2_4_SOLID_ELSET', 'BLADE_2_3_ELSET', 'BLADE_2_4_ELSET', 'TGT_ALL_ELSET', 'BLADE_2_1_SOLID_ELSET', 'BLADE_2_6_SOLID_ELSET', 'BLADE_2_6_ELSET', 'BLADE_2_5_ELSET'}

# %%
m.split_in_groups()  
disk = m.get_submesh('phys_group','DISK')

# %%
ax2 = amfe.plot3D_submesh(disk,plot_nodes=False)
ax2.set_xlim(0,100)
ax2.set_ylim(0,100)
ax2.set_zlim(0,100)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, 100)

# %%
# creating a mechanical component
my_comp = amfe.MechanicalSystem()
my_comp.set_mesh_obj(m)
rho = 7.86E-9 # kg/mm3
E = 210.0E9 # MPa = N/mm2
my_material = amfe.KirchhoffMaterial(E=E, nu=0.3, rho=rho, plane_stress=False)
my_comp.set_domain('DISK',my_material)
print('Number of nodes is equal to %i' %my_comp.mesh_class.no_of_nodes)
# Out:
# Preallocating the stiffness matrix
# Done preallocating stiffness matrix with 23760 elements and 8280 dofs.
# Time taken for preallocation: 0.95 seconds.
# Number of nodes is equal to 2760

# %%
K, f = my_comp.assembly_class.assemble_k_and_f()

# %%
M = my_comp.assembly_class.assemble_m()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-ca7d1850ad31> in <module>
# ----> 1 M = my_comp.assembly_class.assemble_m()
#
# ~/dev/AMFE/amfe/assembly.py in assemble_m(self, u, t)
#     433             u_local = u[indices]
#     434             M = self.mesh.ele_obj[i].m_int(X_local, u_local, t)
# --> 435             fill_csr_matrix(M_csr.indptr, M_csr.indices, M_csr.data, M, indices)
#     436
#     437         return M_csr
#
# ~/dev/AMFE/amfe/assembly.py in fill_csr_matrix(indptr, indices, vals, K, k_indices)
#     111     for i in range(ndof_l):
#     112         for j in range(ndof_l):
# --> 113             l = get_index_of_csr_data(k_indices[i], k_indices[j], indptr, indices)
#     114             vals[l] += K[i,j]
#     115     return
#
# ~/dev/AMFE/amfe/assembly.py in get_index_of_csr_data(i, j, indptr, indices)
#      74     while j != indices[k]:
#      75         # while column j not found search for j in next entry
# ---> 76         k += 1
#      77         # Check if next search would be in next (wrong) row
#      78         if k > indptr[i+1]:
#
# KeyboardInterrupt:

# %%
from scipy import sparse

lu = sparse.linalg.splu(K.tocsc())
Kinv = sparse.linalg.LinearOperator(shape=K.shape,matvec=lambda x :lu.solve(x))

eigval, eigvec = sparse.linalg.eigs(Kinv,k=20,M=M)

# %%
omega = 1.0/np.sqrt(eigval.real)
print(omega)

# %%
eigval
